# %% [markdown]
# <a href="https://colab.research.google.com/github/OptimizationExpert/Pyomo/blob/main/VRP_Circuit_CP_Wiring_nocross.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Developed by Alireza Soroudi
# alireza.soroudi@gmail.com
#
# Linkedin News letter : https://www.linkedin.com/in/soroudi/

# %%
# !pip install ortools
from ortools.sat.python import cp_model # CP-SAT solver
import numpy as np
from random import randint
import random
from math import ceil
import pandas as pd
import matplotlib.pyplot as plt # Data visualization
# Out:
# Requirement already satisfied: ortools in /usr/local/lib/python3.10/dist-packages (9.8.3296)
# Requirement already satisfied: absl-py>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from ortools) (1.25.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (2.2.1)
# Requirement already satisfied: protobuf>=4.25.0 in /usr/local/lib/python3.10/dist-packages (from ortools) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->ortools) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)

# %%
KOLORS = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd",
            "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf",
            "#aec7e8", "#ffbb78", "#98df8a", "#ff9896", "#c5b0d5",
            "#c49c94", "#f7b6d2", "#c7c7c7", "#dbdb8d", "#9edae5",
            "#8c6d31", "#9c9ede", "#637939", "#e7cb94", "#b5cf6b",
            "#cedb9c", "#c7c7c7", "#bd9e39", "#e7969c", "#7b4173"]

# %%
nr, nc  = 11, 14
banned = [104,105,106,107,108 , 91, 92,93,94, 78 , 79, 80, 65, 66, 52, 122]

st_fn = {0:(72,139) ,1:(89,152) , 2:(46,96)}

data = {}
counter = 0
plt.figure(figsize=(8,8))
for r in range(1,1+nr):
  for c in range(1,1+nc):
    counter +=1
    data[counter,'x'] = c
    data[counter,'y'] = r
    plt.text(c-0.25,r, s= str(counter), c = 'w', fontweight = 'bold')
    if counter not in banned:
      plt.scatter(c,r, s= 750, c='k')
    else:
      plt.scatter(c,r, s= 750, c='grey')



for c,(st,fn) in st_fn.items():
    i, j = st,fn
    x1,y1 = data[i,'x'],data[i,'y']
    x2,y2 = data[j,'x'],data[j,'y']
    plt.scatter(x1,y1, s= 750, c=KOLORS[c], zorder = 2)
    plt.scatter(x2,y2, s= 750, c=KOLORS[c], zorder = 2)

plt.xticks(range(1,1+nc))
plt.yticks(range(1,1+nr))
plt.show()
print(counter)
# Out:
# 154

# %%
nodes = [n for n in range(1,154+1) if n not in banned ]

def dist(i,j,data):
  x1,y1 = data[i,'x'],data[i,'y']
  x2,y2 = data[j,'x'],data[j,'y']
  return int(100*np.sqrt( (x1-x2)**2 +(y1-y2)**2))



def check(i,j,n,m,data):
    x1,y1 = data[i,'x'],data[i,'y']
    x2,y2 = data[j,'x'],data[j,'y']

    X1,Y1 = data[n,'x'],data[n,'y']
    X2,Y2 = data[m,'x'],data[m,'y']


    flag = (x2-x1)*(X2-X1) + (y2-y1)*(Y2-Y1)
    if flag == 0 and abs(x2-X2) + abs(y2-Y2) == 1 and abs(x1-X2) + abs(y1-Y2) == 1 and abs(x2-X1) + abs(y2-Y1) == 1 and abs(x1-X2) + abs(y1-Y2) == 1:
      return True
    else:
      return False

# %%
model = cp_model.CpModel()
solver = cp_model.CpSolver()
cars = range(3)

U = {(i,j,c):model.NewBoolVar(f"connection_{i}_{j}_{c}")  for c in cars for i in nodes for j in nodes if i!=j and dist(i,j,data) <142}
assign = {(i,c):model.NewBoolVar(f"assign_{i}_{c}")  for c in cars for i in nodes}

cross = [(i,j,c) for (i,j,c),v in U.items()  if dist(i,j,data) > 100 ]

ban_cross = [ [(i,j,c),(i1,j1,c1) ] for (i,j,c) in cross for (i1,j1,c1) in cross if c>c1  and check(i,j,i1,j1,data) ]

for n in nodes:
  expressions = [assign[n,c] for c in cars ]
  model.AddAtMostOne(expressions)
for c in cars:
  (st,fn) = st_fn[c]
  arcs = [(i,j,v) for (i,j,k),v in U.items() if k ==c]
  arc_in_car = arcs + [(n,n,assign[n,c].Not()) for n in nodes ] + [(st,fn,True)]
  model.AddCircuit(arc_in_car)



#for [(i,j,c),(i1,j1,c1) ] in ban_cross:
#  model.Add(U[i,j,c]+U[i1,j1,c1] <= 1)

# Maximize x
expressions = [v*dist(i,j,data) for (i,j,c),v in U.items() ]
model.Minimize(sum(expressions))

status = solver.Solve(model)

if status == cp_model.OPTIMAL:
  print("OPTIMAL")
elif status == cp_model.FEASIBLE:
  print("FEASIBLE")
elif status == cp_model.INFEASIBLE:
  print("INFEASIBLE")

print(solver.ObjectiveValue())
#print(f"x", solver.Value(x))
# Out:
# OPTIMAL
# 3392.0

# %%
plt.figure(figsize=(8,8))

for n in nodes:
    c = data[n,'x']
    r= data[n,'y']
    plt.text(c-0.25,r, s= str(n), c = 'w', fontweight = 'bold')
    plt.scatter(c,r, s= 750, c='k', alpha = 0.2, zorder = -1)
    if n not in banned:
      plt.scatter(c,r, s= 750, c='k', alpha = 0.8)

for n in banned:
    c = data[n,'x']
    r= data[n,'y']
    plt.text(c-0.25,r, s= str(n), c = 'w', fontweight = 'bold')
    plt.scatter(c,r, s= 750, c='grey', alpha = 0.6, zorder = -1)

for c,(st,fn) in st_fn.items():
    i, j = st,fn
    x1,y1 = data[i,'x'],data[i,'y']
    x2,y2 = data[j,'x'],data[j,'y']
    plt.scatter(x1,y1, s= 750, c=KOLORS[c], zorder = 2)
    plt.scatter(x2,y2, s= 750, c=KOLORS[c], zorder = 2)



for (i,j,c), v in U.items():
    if solver.Value(v)>0:
      x1,y1 = data[i,'x'],data[i,'y']
      x2,y2 = data[j,'x'],data[j,'y']
      plt.plot([x1,x2],[y1,y2], lw= 5 , c = KOLORS[c])
    #plt.text(c-0.25,r, s= str(counter), c = 'w', fontweight = 'bold')
    #plt.scatter(c,r, s= 750, c='k')
plt.xticks(range(1,1+nc))
plt.yticks(range(1,1+nr))
plt.show()
print(counter)
# Out:
# 154
